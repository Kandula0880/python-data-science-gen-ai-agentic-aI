# %% [markdown]
# # Number and string

# %%
9
# Out:
# 9

# %%
9+9
# Out:
# 18

# %%
9 - 9
# Out:
# 0

# %%
10/2 # division always returns a floating - pointnumbers
# Out:
# 5.0

# %%
10//2
# Out:
# 5

# %%
3*2
# Out:
# 6

# %%
3**2
# Out:
# 9

# %%
3**3
# Out:
# 27

# %%
_ # it store previous output value
# Out:
# 27

# %%
_+3
# Out:
# 30

# %%
_-10
# Out:
# 20

# %%
_*2
# Out:
# 40

# %%
_/2
# Out:
# 20.0

# %%
_//2
# Out:
# 10.0

# %%
3*2+5-1-3
# Out:
# 7

# %%
math.pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 math.pi
#
# NameError: name 'math' is not defined

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.ceil(9.2)
# Out:
# 10

# %%
math.floor(9.2)
# Out:
# 9

# %%
kandula kasi reddy
# Out:
#   Cell In[22], line 1
#     kandula kasi reddy
#             ^
# SyntaxError: invalid syntax

# %%
'kandula kasi reddy'
# Out:
# 'kandula kasi reddy'

# %%
"kandula kasi reddy"
# Out:
# 'kandula kasi reddy'

# %%
'''kandula kasi reddy'''
# Out:
# 'kandula kasi reddy'

# %%
'kandula kasi
reddy'
# Out:
#   Cell In[26], line 1
#     'kandula kasi
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"kandula kasi
reddy"
# Out:
#   Cell In[27], line 1
#     "kandula kasi
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''kandula kasi
reddy'''
# Out:
# 'kandula kasi\nreddy'

# %%
_
# Out:
# 'kandula kasi\nreddy'

# %%
s = "hello"

# %%
s
# Out:
# 'hello'

# %%
s[0]
# Out:
# 'h'

# %%
s[1]
# Out:
# 'e'

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 s[10]
#
# IndexError: string index out of range

# %%
a = hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 a = hello
#
# NameError: name 'hello' is not defined

# %% [markdown]
# # variables

# %%
# variables does not start with numbers but it ends with number.
# variables is case sensitive(if you mention lower case and call the value in lower case only.
# special characters are not allowed in variable.
# only _ is allowed.
# keywords cannot define as variable.

# %%
v = 5 # variable declaration
v
# Out:
# 5

# %%
id(v) # address of the memory location
# Out:
# 140713988105256

# %%
5 = v
# Out:
#   Cell In[41], line 1
#     5 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
v5 = 5

# %%
v5
# Out:
# 5

# %%
v@ = 4
# Out:
#   Cell In[44], line 1
#     v@ = 4
#        ^
# SyntaxError: invalid syntax

# %%
v# = 1
# Out:
# 5

# %%
a = 7
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 a = 7
# ----> 2 A
#
# NameError: name 'A' is not defined

# %%
v_ = 10

# %%
v_
# Out:
# 10

# %%
for = 4
# Out:
#   Cell In[50], line 1
#     for = 4
#         ^
# SyntaxError: invalid syntax

# %%
For = 3

# %%
For
# Out:
# 3

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
else = 4
# Out:
#   Cell In[55], line 1
#     else = 4
#     ^
# SyntaxError: invalid syntax

# %%
kasi = 3

# %%
kasi
# Out:
# 3

# %%
'py' 'thon' # Two  or more strings  literals next to each other are automatically concatenated.
# Out:
# 'python'

# %%
'py'  "thon"
# Out:
# 'python'

# %%
a = 'py'
a = 'thon'# we cannot define same variable in two times
# if want to concatenate variables or a variable and a literal use +

# %%
a
# Out:
# 'thon'

# %%
'py'+a
# Out:
# 'python'
