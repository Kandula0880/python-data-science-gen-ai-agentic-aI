# %%
a = math.sqrt(25)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a = math.sqrt(25)
#       2 a
#
# NameError: name 'math' is not defined

# %%
import math

# %%
a = math.sqrt(25)
a
# Out:
# 5.0

# %%
math.pow(5,3)
# Out:
# 125.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.ceil(2.5)
# Out:
# 3

# %%
math.floor(2.5)
# Out:
# 2

# %%
from math import sqrt,pow,ceil,floor
print(sqrt(100))
print(pow(5,2))
print(ceil(5.5))
print(floor(5.5))
# Out:
# 10.0
# 25.0
# 6
# 5

# %%
from math import *
print(sqrt(100))
print(pow(5,2))
print(ceil(5.5))
print(floor(5.5))
# Out:
# 10.0
# 25.0
# 6
# 5

# %%
a1 = m.sqrt(25)
a1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a1 = m.sqrt(25)
#       2 a1
#
# NameError: name 'm' is not defined

# %%
import math as m

# %%
a1 = m.sqrt(25)
a1
# Out:
# 5.0

# %%
from m import *
print(sqrt(100))
print(pow(5,2))
print(ceil(5.5))
print(floor(5.5))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from m import *
#       2 print(sqrt(100))
#       3 print(pow(5,2))
#
# ModuleNotFoundError: No module named 'm'

# %% [markdown]
# # Input

# %%
x = input()
x
# Out:
#  5
# '5'

# %%
x1 = input()
y1 = input()
print(x1)
print(y1)
# Out:
#  2
#  3
# 2
# 3

# %%
x =  input()
y = input()
z = x + y
print(z)
# Out:
#  2
#  3
# 23

# %%
x = input()
x1 = int(x)
y = input()
y1 = int(y)
z = x1 + y1
print(z)
# Out:
#  2
#  3
# 5

# %%
x = int(input())
y = int(input())
print(x+y)
# Out:
#  5
#  5
# 10

# %%
x = int(input('Enter a 1st number:'))
y = int(input('Enter a 2nd number:'))
print('Addition of x and y is',x+y)
# Out:
# Enter a 1st number: 10
# Enter a 2nd number: 20
# Addition of x and y is 30

# %%
a = input()
print(a)
# Out:
#  "kasi"
# "kasi"

# %%
a = input()
print(a)
# Out:
#  kasi
# kasi

# %%
a = float(input())
print(a)
# Out:
#  1
# 1.0

# %%
a = input()[0]
print(a)
# Out:
#  kasi
# k

# %%
a = input()[8:18]
print(a)
# Out:
#  kandula kasi reddy
# kasi reddy

# %%
b = input('Enter a expression:')
print(b)
# Out:
# Enter a expression: 2+1-2*5
# 2+1-2*5

# %%
b = int(input('Enter a expression:'))
print(b)
# Out:
# Enter a expression: 2+1-2*5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 b = int(input('Enter a expression:'))
#       2 print(b)
#
# ValueError: invalid literal for int() with base 10: '2+1-2*5'

# %%
b = eval(input('Enter a expression:'))
print(b)
# Out:
# Enter a expression: 2+1-2*5
# -7
