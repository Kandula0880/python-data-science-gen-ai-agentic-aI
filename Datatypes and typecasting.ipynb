# %%
i = 32
i
# Out:
# 32

# %%
type(i)
# Out:
# int

# %%
f = 1.2
f
# Out:
# 1.2

# %%
type(f)
# Out:
# float

# %%
f1 = 2e3
f1 # e represents power of 10
# Out:
# 2000.0

# %%
f2 = 2E3
f2
# Out:
# 2000.0

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b1 = False
b1
# Out:
# False

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True + True
# Out:
# 2

# %%
True - True*False+True
# Out:
# 2

# %%
c = 1+2j
c
# Out:
# (1+2j)

# %%
c.real # by default it gives flaot value
# Out:
# 1.0

# %%
c.imag
# Out:
# 2.0

# %%
c1 = 1+2j
c2 = 1+2J
print(c1+c2)
print(c1-c2)
# Out:
# (2+4j)
# 0j

# %%
type(c)
# Out:
# complex

# %%
s = "hello python"
s
# Out:
# 'hello python'

# %%
s[1]
# Out:
# 'e'

# %%
s[8]
# Out:
# 't'

# %%
s[1:5]
# Out:
# 'ello'

# %%
s[::-1]
# Out:
# 'nohtyp olleh'

# %%
s[-6]
# Out:
# 'p'

# %%
s
# Out:
# 'hello python'

# %%
s[-100:-4]
# Out:
# 'hello py'

# %%
s[-10:-4] # llo py
# Out:
# 'llo py'

# %%
s[:-1]
# Out:
# 'hello pytho'

# %%
s[-1:]
# Out:
# 'n'

# %%
s[10:2:2]
# Out:
# ''

# %%
s[2:10:2]
# Out:
# 'lopt'

# %%
a = 10
b = 20
c = 20
add = a + b + c
print(a + b + c)
# Out:
# 50

# %%
print("The addition of",a, "and", b, "and",c,"is=", add)
# Out:
# The addition of 10 and 20 and 20 is= 50

# %%
print("The addition of {} and {} and {} is = {}".format(a,b,c,add))
# Out:
# The addition of 10 and 20 and 20 is = 50

# %%
# Type casting

# %%
print(int(1.3))
print(int('1'))
print(int(True))
print(int(1+2j)) # complex to int is not possiable
# Out:
# 1
# 1
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       2 print(int('1'))
#       3 print(int(True))
# ----> 4 print(int(1+2j)) # complex to int is not possiable
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(1,2) # it takes only one argument
# string with text also is not possiable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 int(1,2) # it takes only one argument
#       2 # string with text also is not possiable
#
# TypeError: int() can't convert non-string with explicit base

# %%
print(float(1))
print(float('1'))
print(float(False))
print(float(1+4j))
# Out:
# 1.0
# 1.0
# 0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       2 print(float('1'))
#       3 print(float(False))
# ----> 4 print(float(1+4j))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
print(bool(1))
print(bool(1.2))
print(bool('1'))
print(bool(1+2J))
# Out:
# True
# True
# True
# True

# %%
bool() # without argument it'll prints False and with arguments it'll print True
# Out:
# False

# %%
print(str(1))
print(str(1.1))
print(str(True))
print(str(1+3j))
# Out:
# 1
# 1.1
# True
# (1+3j)

# %%
str(1)
# Out:
# '1'

# %%
str(False)
# Out:
# 'False'

# %%
str(1.1)
# Out:
# '1.1'

# %%
str(1,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 str(1,1)
#
# TypeError: str() argument 'encoding' must be str, not int

# %%
print(complex(1))
print(complex(1.1))
print(complex('1'))
print(complex(True))
# Out:
# (1+0j)
# (1.1+0j)
# (1+0j)
# (1+0j)

# %%
complex('1',2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 complex('1',2j)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('1','2j')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 complex('1','2j')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(1,2)
# Out:
# (1+2j)
