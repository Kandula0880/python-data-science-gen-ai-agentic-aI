# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image # python Imageing library

# %%
image = Image.open(r"ele.jfif")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=208x148>

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img = np.asarray(image)
img
# Out:
# array([[[194, 196, 208],
#         [207, 209, 221],
#         [217, 221, 232],
#         ...,
#         [182, 196, 209],
#         [180, 194, 207],
#         [178, 192, 205]],
#
#        [[196, 198, 210],
#         [210, 212, 224],
#         [220, 224, 235],
#         ...,
#         [184, 198, 211],
#         [183, 197, 210],
#         [182, 196, 209]],
#
#        [[196, 198, 210],
#         [209, 213, 224],
#         [221, 225, 236],
#         ...,
#         [186, 200, 213],
#         [187, 201, 214],
#         [187, 201, 214]],
#
#        ...,
#
#        [[142, 111,  67],
#         [131, 100,  56],
#         [138, 109,  65],
#         ...,
#         [141, 115,  64],
#         [139, 113,  62],
#         [141, 116,  62]],
#
#        [[138, 107,  63],
#         [125,  94,  50],
#         [123,  94,  50],
#         ...,
#         [148, 122,  71],
#         [143, 117,  66],
#         [143, 118,  64]],
#
#        [[134, 103,  59],
#         [124,  93,  49],
#         [114,  85,  41],
# ...
