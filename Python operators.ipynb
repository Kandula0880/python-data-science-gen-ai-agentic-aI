# %% [markdown]
# # Operators

# %% [markdown]
# # 1. Arithmatic operators

# %%
a = 2
b = 3
print(a+b)
# Out:
# 5

# %%
a+b
# Out:
# 5

# %%
a - b
# Out:
# -1

# %%
a * b
# Out:
# 6

# %%
a/b
# Out:
# 0.6666666666666666

# %%
a//b
# Out:
# 0

# %%
a**2
# Out:
# 4

# %%
a%b
# Out:
# 2

# %%
_+b
# Out:
# 5

# %%
_*2
# Out:
# 10

# %% [markdown]
# # Assignment operator

# %%
a1 = 5
b1 = 3

# %%
a1 += b1

# %%
a1
# Out:
# 8

# %%
b1 -= a1

# %%
b1
# Out:
# -5

# %%
a1 -= b1

# %%
a1
# Out:
# 13

# %%
a1
# Out:
# 13

# %%
b1
# Out:
# -5

# %%
a1 *= b1

# %%
a1
# Out:
# -65

# %%
a = 10
b = 2

# %%
a /= b

# %%
a
# Out:
# 5.0

# %%
a //= b

# %%
a
# Out:
# 2.0

# %%
a **= b

# %%
a
# Out:
# 4.0

# %%
a += b

# %%
a
# Out:
# 6.0

# %% [markdown]
# # Unary operator

# %%
a = 5
a
# Out:
# 5

# %%
b = -(a)
b
# Out:
# -5

# %% [markdown]
# # Relational operator

# %%
a = 2
b = 8

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a1 = 10
b1 = 5

# %%
a1 > b1
# Out:
# True

# %%
b1 > a1
# Out:
# False

# %%
a1 < b1
# Out:
# False

# %%
b1 < a1
# Out:
# True

# %%
a1 <= b1
# Out:
# False

# %%
a1 >= b1
# Out:
# True

# %% [markdown]
# # Logical operators

# %%
a1 = 15
b1 = 4

# %%
print(a1)
print(b1)
# Out:
# 15
# 4

# %%
a1 > b1 and a1 < b1
# Out:
# False

# %%
a1 < b1 and a1 > b1
# Out:
# False

# %%
a1 > b1 and b1 < a1
# Out:
# True

# %%
a1 > b1 or a1 < b1
# Out:
# True

# %%
x = True
x
# Out:
# True

# %%
type(x)
# Out:
# bool

# %%
not x
# Out:
# False

# %%
x1 = not x
x1
# Out:
# False

# %% [markdown]
# # swap two numbers

# %%
a11 = 5
a22 = 7

# %%
print(a11)
print(a22)
# Out:
# 5
# 7

# %%
a11,a22 = a22,a11 # method one with out using third variable

# %%
a11
# Out:
# 5

# %%
a22
# Out:
# 7

# %%
a0 = 2
b0 = 3

# %%
a0 = b0
b0 = a0

# %%
print(a0)
print(b0)
# Out:
# 3
# 3

# %%
a0 = b0

# %%
a0
# Out:
# 3

# %%
a33 = 4
a44 = 9

# %%
print(a33)
print(a44)
# Out:
# 4
# 9

# %%
temp = a33 # 4
a33 = a44 # 9
a44 = temp # 4
# here i used with third variable

# %%
print(a33)
print(a44)
# Out:
# 9
# 4

# %%
b11 = 2
b12 = 8

# %%
print(b11)
print(b12)
# Out:
# 2
# 8

# %%
# 3rd method
b11 = b11 + b12
b12 = b11 - b12
b11 = b11 - b12

# %%
print(b11)
print(b12)
# Out:
# 8
# 2

# %% [markdown]
# # Number system

# %%
26
# Out:
# 26

# %%
bin(26)
# Out:
# '0b11010'

# %%
int(0b11010)
# Out:
# 26

# %%
oct(57)
# Out:
# '0o71'

# %%
int(0o71)
# Out:
# 57

# %%
0x4
# Out:
# 4

# %%
0xa
# Out:
# 10

# %%
0xc
# Out:
# 12

# %%
0xe
# Out:
# 14

# %%
0x5
# Out:
# 5

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(12)
# Out:
# '0xc'

# %%
0x18
# Out:
# 24

# %%
0x16
# Out:
# 22

# %%
0x25
# Out:
# 37

# %% [markdown]
# # Bitwise operator

# %%
# 1. complement operator

# %%
~ 4
# Out:
# -5

# %%
~ -10
# Out:
# 9

# %%
~ 10
# Out:
# -11

# %%
# 2. and(&)

# %%
15 & 23
# Out:
# 7

# %%
bin(15)
# Out:
# '0b1111'

# %%
bin(23)
# Out:
# '0b10111'

# %%
13 & 17
# Out:
# 1

# %%
14 | 10
# Out:
# 14

# %%
18 | 12
# Out:
# 30

# %%
21 | 32
# Out:
# 53

# %%
bin(21)
# Out:
# '0b10101'

# %%
bin(32)
# Out:
# '0b100000'

# %%
17 ^ 14
# Out:
# 31

# %%
12<<2
# Out:
# 48

# %%
12>>2
# Out:
# 3
